# %%
import numpy as np
from keras.models import Sequential, model_from_json
from keras.layers.core import Dense

# cargamos las 4 combinaciones de las compuertas XOR
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# y estos son los resultados que se obtienen, en el mismo orden
target_data = np.array([[0],[1],[1],[0]], "float32")

model = Sequential()
#Primer parametro es el numero de neuronas para la capa oculta, el segundo la dimencion 
#de la capa de entrada y la tercera la funcion de activacion.
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
#En total tenemos una red neuronal de 3 pacas

# %% [markdown]
# ![image.png](attachment:image.png)<img="">

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

model.fit(training_data, target_data, epochs=1000)

# evaluamos el modelo
scores = model.evaluate(training_data, target_data)

print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print (model.predict(training_data).round())
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 76ms/step - loss: 0.2670 - binary_accuracy: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s 284us/step - loss: 0.2663 - binary_accuracy: 0.2500
# Epoch 3/1000
# 4/4 [==============================] - 0s 388us/step - loss: 0.2655 - binary_accuracy: 0.2500
# Epoch 4/1000
# 4/4 [==============================] - 0s 403us/step - loss: 0.2648 - binary_accuracy: 0.2500
# Epoch 5/1000
# 4/4 [==============================] - 0s 448us/step - loss: 0.2640 - binary_accuracy: 0.2500
# Epoch 6/1000
# 4/4 [==============================] - 0s 611us/step - loss: 0.2633 - binary_accuracy: 0.2500
# Epoch 7/1000
# 4/4 [==============================] - 0s 509us/step - loss: 0.2626 - binary_accuracy: 0.2500
# Epoch 8/1000
# 4/4 [==============================] - 0s 406us/step - loss: 0.2620 - binary_accuracy: 0.2500
# Epoch 9/1000
# 4/4 [==============================] - 0s 630us/step - loss: 0.2613 - binary_accuracy: 0.2500
# ...

# %% [markdown]
#  ### Evaluamos y Predecimos

# %%
scores = model.evaluate(training_data, target_data)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 4/4 [==============================] - 0s 942us/step
#
# binary_accuracy: 100.00%

# %% [markdown]
# > Y vemos que tuvimos un 100% de precisión
#
# > Y hacemos las 4 predicciones posibles de XOR, pasando nuestras entradas:

# %%
print (model.predict(training_data).round())
# Out:
# [[ 0.]
#  [ 1.]
#  [ 1.]
#  [ 0.]]

# %% [markdown]
# ### Guardar la red y usarla

# %%
# serializar el modelo a JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serializar los pesos a HDF5
model.save_weights("model.h5")
print("Modelo Guardado!")
# Out:
# Modelo Guardado!

# %% [markdown]
# >  #### Cargar json y crear el modelo

# %%
with open('model.json','r') as f:
    json = f.read()
model = model_from_json(json)

model.load_weights("model.h5")
print("Cargado modelo desde disco.")
 
# Compilar modelo cargado y listo para usar.
model.compile(loss='mean_squared_error', 
              optimizer='adam', 
              metrics=['binary_accuracy'])
# Out:
# Cargado modelo desde disco.

# %%
#model.fit(training_data, target_data, epochs=1000)

# evaluamos el modelo
scores = model.evaluate(training_data, target_data)

print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print (model.predict(training_data).round())
# Out:
# 4/4 [==============================] - 0s 76ms/step
#
# binary_accuracy: 100.00%
# [[ 0.]
#  [ 1.]
#  [ 1.]
#  [ 0.]]
